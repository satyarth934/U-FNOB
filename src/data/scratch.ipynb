# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
exec_times = np.loadtxt("exec_times.txt")
plt.plot(exec_times, '.')
plt.show()

# %%
exec_times = np.loadtxt("exec_times_v2.txt")
plt.plot(exec_times, '.')
plt.show()
